# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
def compute_max_accuracy(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['Accuracy']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
    
def compute_max_P(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['Precision Macro']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
    
def compute_max_R(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['Recall Macro']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
    
def compute_max_F(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['F1 Score Macro']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
    
    
def compute_max_Pm(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['Precision Micro']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
    
def compute_max_Rm(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['Recall Micro']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
    
def compute_max_Fm(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['F1 Score Micro']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
# Specify the top-level
# Specify the top-level directory
top_directory = './models'  # Assuming the script is in the same directory as the CSV files

# Create an empty DataFrame to store results
result_df = []

# Loop through each subdirectory
for directory in os.listdir(top_directory):
    directory_path = os.path.join(top_directory, directory)
    
    # Check if the item is a directory
    if os.path.isdir(directory_path):
        # Loop through each file in the directory
        for file_name in os.listdir(directory_path):
            if file_name.endswith('.csv'):
                file_path = os.path.join(directory_path, file_name)
                print(file_path)

                # Compute the maximum accuracy for the current CSV file
                max_accuracy = compute_max_accuracy(file_path)
                R = compute_max_R(file_path)
                P = compute_max_P(file_path)
                F = compute_max_F(file_path)
                Rm = compute_max_Rm(file_path)
                Pm = compute_max_Pm(file_path)
                Fm = compute_max_Fm(file_path)
                # Append the result to the DataFrame
                if max_accuracy is not None:
                    result_df.append({'Directory Name': directory, 'Max Accuracy': max_accuracy,
                                      'Recall Macro':R, "Precision Macro":P, "F1 Score Macro":F,
                                     'Recall Micro':Rm, "Precision Micro":Pm, "F1 Score Micro":Fm})

# Display the result DataFrame
print(result_df)
# Out:
# ./models/B16_N8_FC2_K5_AP20_fold1/B16_N8_FC2_K5_AP20_fold1.csv
# ./models/B16_N8_FC2_K5_AP20_fold7/B16_N8_FC2_K5_AP20_fold7.csv
# ./models/B16_N8_FC2_K5_AP20_fold3/B16_N8_FC2_K5_AP20_fold3.csv
# ./models/B16_N8_FC2_K5_AP20_fold9/B16_N8_FC2_K5_AP20_fold9.csv
# ./models/B16_N8_FC2_K5_AP20_fold2/B16_N8_FC2_K5_AP20_fold2.csv
# ./models/B16_N8_FC2_K5_AP20_fold4/B16_N8_FC2_K5_AP20_fold4.csv
# ./models/B16_N8_FC2_K5_AP20_fold5/B16_N8_FC2_K5_AP20_fold5.csv
# ./models/B16_N8_FC2_K5_AP20_fold8/B16_N8_FC2_K5_AP20_fold8.csv
# ./models/B16_N8_FC2_K5_AP20_fold6/B16_N8_FC2_K5_AP20_fold6.csv
# ./models/B16_N8_FC2_K5_AP20_fold0/B16_N8_FC2_K5_AP20_fold0.csv
# [{'Directory Name': 'B16_N8_FC2_K5_AP20_fold1', 'Max Accuracy': 0.6527672479150872, 'Recall Macro': 0.6559037955797609, 'Precision Macro': 0.6618428210669258, 'F1 Score Macro': 0.6550964474986734, 'Recall Micro': 0.6527672479150872, 'Precision Micro': 0.6527672479150872, 'F1 Score Micro': 0.6527672479150872}, {'Directory Name': 'B16_N8_FC2_K5_AP20_fold7', 'Max Accuracy': 0.6338134950720242, 'Recall Macro': 0.6356834998923807, 'Precision Macro': 0.6511443807368714, 'F1 Score Macro': 0.6373392612049688, 'Recall Micro': 0.6338134950720242, 'Precision Micro': 0.6338134950720242, 'F1 Score Micro': 0.6338134950720242}, {'Directory Name': 'B16_N8_FC2_K5_AP20_fold3', 'Max Accuracy': 0.6459438968915845, 'Recall Macro': 0.6514704140727832, 'Precision Macro': 0.6562573411150797, 'F1 Score Macro': 0.6510951140544601, 'Recall Micro': 0.6459438968915845, 'Precision Micro': 0.6459438968915845, 'F1 Score Micro': 0.6459438968915845}, {'Directory Name': 'B16_N8_FC2_K5_AP20_fold9', 'Max Accuracy': 0.6368460955269143, 'Recall Macro': 0.6426354239092802, 'Precision Macro': 0.6552438031421617, 'F1 Score Macro': 0.643858886719906, 'Recall Micro': 0.6368460955269143, 'Precision Micro': 0.6368460955269143, 'F1 Score Micro': 0.6368460955269143}, {'Directory Name': 'B16_N8_FC2_K5_AP20_fold2', 'Max Accuracy': 0.6360879454131918, 'Recall Macro': 0.6414739643447512, 'Precision Macro': 0.6387075829797595, 'F1 Score Macro': 0.6382899610394168, 'Recall Micro': 0.6360879454131918, 'Precision Micro': 0.6360879454131918, 'F1 Score Micro': 0.6360879454131918}, {'Directory Name': 'B16_N8_FC2_K5_AP20_fold4', 'Max Accuracy': 0.6330553449583017, 'Recall Macro': 0.632776263425558, 'Precision Macro': 0.639112408295349, 'F1 Score Macro': 0.6321371145334445, 'Recall Micro': 0.6330553449583017, 'Precision Micro': 0.6330553449583017, 'F1 Score Micro': 0.6330553449583017}, {'Directory Name': 'B16_N8_FC2_K5_AP20_fold5', 'Max Accuracy': 0.6482183472327521, 'Recall Macro': 0.6531716221754822, 'Precision Macro': 0.6673028658089722, 'F1 Score Macro': 0.6520769826282218, 'Recall Micro': 0.6482183472327521, 'Precision Micro': 0.6482183472327521, 'F1 Score Micro': 0.6482183472327521}, {'Directory Name': 'B16_N8_FC2_K5_AP20_fold8', 'Max Accuracy': 0.6618650492797574, 'Recall Macro': 0.6605877801923009, 'Precision Macro': 0.656939885357222, 'F1 Score Macro': 0.6577558267691801, 'Recall Micro': 0.6618650492797574, 'Precision Micro': 0.6618650492797574, 'F1 Score Micro': 0.6618650492797574}, {'Directory Name': 'B16_N8_FC2_K5_AP20_fold6', 'Max Accuracy': 0.6254738438210766, 'Recall Macro': 0.6244899064964493, 'Precision Macro': 0.6494673873026363, 'F1 Score Macro': 0.6260026921782241, 'Recall Micro': 0.6254738438210766, 'Precision Micro': 0.6254738438210766, 'F1 Score Micro': 0.6254738438210766}, {'Directory Name': 'B16_N8_FC2_K5_AP20_fold0', 'Max Accuracy': 0.6482183472327521, 'Recall Macro': 0.6493436659160629, 'Precision Macro': 0.6514626030684176, 'F1 Score Macro': 0.6473512729680402, 'Recall Micro': 0.6482183472327521, 'Precision Micro': 0.6482183472327521, 'F1 Score Micro': 0.6482183472327521}]

# %%
df = pd.DataFrame(result_df)
df["fold"] = df["Directory Name"].apply(lambda x: x.split("fold")[1])
df = df[['fold','Max Accuracy','Recall Macro','Recall Micro','Precision Macro','Precision Micro','F1 Score Macro','F1 Score Micro']].sort_values(by="fold")
df.to_csv("fold_results.csv")
# Out:
#   fold  Max Accuracy  Recall Macro  Recall Micro  Precision Macro  \
# 9    0      0.648218      0.649344      0.648218         0.651463
# 0    1      0.652767      0.655904      0.652767         0.661843
# 4    2      0.636088      0.641474      0.636088         0.638708
# 2    3      0.645944      0.651470      0.645944         0.656257
# 5    4      0.633055      0.632776      0.633055         0.639112
# 6    5      0.648218      0.653172      0.648218         0.667303
# 8    6      0.625474      0.624490      0.625474         0.649467
# 1    7      0.633813      0.635683      0.633813         0.651144
# 7    8      0.661865      0.660588      0.661865         0.656940
# 3    9      0.636846      0.642635      0.636846         0.655244
#
#    Precision Micro  F1 Score Macro  F1 Score Micro
# 9         0.648218        0.647351        0.648218
# 0         0.652767        0.655096        0.652767
# 4         0.636088        0.638290        0.636088
# 2         0.645944        0.651095        0.645944
# 5         0.633055        0.632137        0.633055
# 6         0.648218        0.652077        0.648218
# 8         0.625474        0.626003        0.625474
# 1         0.633813        0.637339        0.633813
# 7         0.661865        0.657756        0.661865
# 3         0.636846        0.643859        0.636846

# %%
df
# Out:
#   fold  Max Accuracy  Recall Macro  Recall Micro  Precision Macro  \
# 9    0      0.648218      0.649344      0.648218         0.651463
# 0    1      0.652767      0.655904      0.652767         0.661843
# 4    2      0.636088      0.641474      0.636088         0.638708
# 2    3      0.645944      0.651470      0.645944         0.656257
# 5    4      0.633055      0.632776      0.633055         0.639112
# 6    5      0.648218      0.653172      0.648218         0.667303
# 8    6      0.625474      0.624490      0.625474         0.649467
# 1    7      0.633813      0.635683      0.633813         0.651144
# 7    8      0.661865      0.660588      0.661865         0.656940
# 3    9      0.636846      0.642635      0.636846         0.655244
#
#    Precision Micro  F1 Score Macro  F1 Score Micro
# 9         0.648218        0.647351        0.648218
# 0         0.652767        0.655096        0.652767
# 4         0.636088        0.638290        0.636088
# 2         0.645944        0.651095        0.645944
# 5         0.633055        0.632137        0.633055
# 6         0.648218        0.652077        0.648218
# 8         0.625474        0.626003        0.625474
# 1         0.633813        0.637339        0.633813
# 7         0.661865        0.657756        0.661865
# 3         0.636846        0.643859        0.636846
