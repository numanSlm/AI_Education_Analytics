# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
def compute_max_accuracy(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['Accuracy']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
    
def compute_max_P(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['Precision Macro']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
    
def compute_max_R(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['Recall Macro']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
    
def compute_max_F(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if 'Accuracy' column exists
    if 'Accuracy' in data.columns:
        # Extract the 'Accuracy' column
        accuracy_column = data['F1 Score Macro']

        # Find the maximum value in the 'Accuracy' column
        max_acc = accuracy_column.argmax()
        return accuracy_column[max_acc]
    else:
        return "Hel"
# Specify the top-level
# Specify the top-level directory
top_directory = '.'  # Assuming the script is in the same directory as the CSV files

# Create an empty DataFrame to store results
result_df = []

# Loop through each subdirectory
for directory in os.listdir(top_directory):
    directory_path = os.path.join(top_directory, directory)
    
    # Check if the item is a directory
    if os.path.isdir(directory_path):
        # Loop through each file in the directory
        for file_name in os.listdir(directory_path):
            if file_name.endswith('.csv'):
                file_path = os.path.join(directory_path, file_name)
                print(file_path)

                # Compute the maximum accuracy for the current CSV file
                max_accuracy = compute_max_accuracy(file_path)
                R = compute_max_R(file_path)
                P = compute_max_P(file_path)
                F = compute_max_F(file_path)
                # Append the result to the DataFrame
                if max_accuracy is not None:
                    result_df.append({'Directory Name': directory, 'Max Accuracy': max_accuracy,
                                      'Recall':R, "Precision":P, "F1 Score":F})

# Display the result DataFrame
print(result_df)
# Out:
# ./B32_N4_FC1_K5_AP20/B4FC1K5AP20.csv
# ./B16_N8_FC2_K3_AP20/B8FC2K3AP20.csv
# ./B16_N12_FC4_K5_AP20/B12FC4K5AP20.csv
# ./B16_N8_FC2_K7_AP20/B8FC2K7AP20.csv
# ./B32_N8_FC2_K5_AP20/B8FC2K5AP20.csv
# ./B32_N4_FC1_K3_AP20/B4FC1K3AP20.csv
# ./B16_N12_FC4_K3_AP20/B12FC4K3AP20.csv
# ./B16_N4_FC1_K5_AP20/B4FC1K5AP20.csv
# ./B16_N8_FC2_K5_AP20/B8FC2K5AP20.csv
# ./B16_N12_FC4_K7_AP20/B12FC4K7AP20.csv
# ./B32_N4_FC1_K7_AP20/B4FC1K7AP20.csv
# ./B16_N4_FC1_K7_AP20/B4FC1K7AP20.csv
# ./B32_N8_FC2_K7_AP20/B8FC2K7AP20.csv
# ./B16_N4_FC1_K3_AP20/B4FC1K3AP20.csv
# ./B32_N8_FC2_K3_AP20/B8FC2K3AP20.csv
# ...

# %%
compute_max_accuracy("./B32_N4_FC1_K7_AP20/B4FC1K7AP20.csv")
# Out:
# 0.5779775280898877

# %%
df = pd.DataFrame(result_df)

# %%
df
# Out:
#          Directory Name  Max Accuracy    Recall  Precision  F1 Score
# 0    B32_N4_FC1_K5_AP20      0.592360  0.595048   0.629317  0.590056
# 1    B16_N8_FC2_K3_AP20      0.604494  0.600417   0.620104  0.597360
# 2   B16_N12_FC4_K5_AP20      0.599551  0.600469   0.619881  0.596407
# 3    B16_N8_FC2_K7_AP20      0.617978  0.611103   0.627087  0.609395
# 4    B32_N8_FC2_K5_AP20      0.612135  0.615304   0.652023  0.613317
# 5    B32_N4_FC1_K3_AP20      0.592360  0.595532   0.622576  0.596638
# 6   B16_N12_FC4_K3_AP20      0.616629  0.612040   0.638428  0.620881
# 7    B16_N4_FC1_K5_AP20      0.596404  0.598403   0.612813  0.595999
# 8    B16_N8_FC2_K5_AP20      0.623371  0.621407   0.654631  0.611707
# 9   B16_N12_FC4_K7_AP20      0.609888  0.612808   0.620492  0.608026
# 10   B32_N4_FC1_K7_AP20      0.577978  0.582606   0.592769  0.584087
# 11   B16_N4_FC1_K7_AP20      0.583820  0.580199   0.619654  0.579667
# 12   B32_N8_FC2_K7_AP20      0.607191  0.610399   0.651253  0.608782
# ...

# %%
def func1(name):
    s = name.split("_")
    Num_Channels = int(s[0].replace("B",""))
    Num_ResBlocks = int(s[1].replace("N",""))
    Num_FC_Layers = int(s[2].replace("FC",""))
    Kernel_Size = int(s[3].replace("K",""))
    return Num_Channels

def func2(name):
    s = name.split("_")
    Num_Channels = int(s[0].replace("B",""))
    Num_ResBlocks = int(s[1].replace("N",""))
    Num_FC_Layers = int(s[2].replace("FC",""))
    Kernel_Size = int(s[3].replace("K",""))
    return Num_ResBlocks

def func3(name):
    s = name.split("_")
    Num_Channels = int(s[0].replace("B",""))
    Num_ResBlocks = int(s[1].replace("N",""))
    Num_FC_Layers = int(s[2].replace("FC",""))
    Kernel_Size = int(s[3].replace("K",""))
    return Num_FC_Layers

def func4(name):
    s = name.split("_")
    Num_Channels = int(s[0].replace("B",""))
    Num_ResBlocks = int(s[1].replace("N",""))
    Num_FC_Layers = int(s[2].replace("FC",""))
    Kernel_Size = int(s[3].replace("K",""))
    return Kernel_Size

# %%
df["Num_Channels"] = df.apply(lambda x: func1(x["Directory Name"]),axis=1)
df["Num_ResBlocks"] = df.apply(lambda x: func2(x["Directory Name"]),axis=1)
df["Num_FC_Layers"] = df.apply(lambda x: func3(x["Directory Name"]),axis=1)
df["Kernel_Size"] = df.apply(lambda x: func4(x["Directory Name"]),axis=1)

# %%
df
# Out:
#          Directory Name  Max Accuracy    Recall  Precision  F1 Score  \
# 0    B32_N4_FC1_K5_AP20      0.592360  0.595048   0.629317  0.590056
# 1    B16_N8_FC2_K3_AP20      0.604494  0.600417   0.620104  0.597360
# 2   B16_N12_FC4_K5_AP20      0.599551  0.600469   0.619881  0.596407
# 3    B16_N8_FC2_K7_AP20      0.617978  0.611103   0.627087  0.609395
# 4    B32_N8_FC2_K5_AP20      0.612135  0.615304   0.652023  0.613317
# 5    B32_N4_FC1_K3_AP20      0.592360  0.595532   0.622576  0.596638
# 6   B16_N12_FC4_K3_AP20      0.616629  0.612040   0.638428  0.620881
# 7    B16_N4_FC1_K5_AP20      0.596404  0.598403   0.612813  0.595999
# 8    B16_N8_FC2_K5_AP20      0.623371  0.621407   0.654631  0.611707
# 9   B16_N12_FC4_K7_AP20      0.609888  0.612808   0.620492  0.608026
# 10   B32_N4_FC1_K7_AP20      0.577978  0.582606   0.592769  0.584087
# 11   B16_N4_FC1_K7_AP20      0.583820  0.580199   0.619654  0.579667
# 12   B32_N8_FC2_K7_AP20      0.607191  0.610399   0.651253  0.608782
# ...

# %%
df["Accuracy"] = df["Max Accuracy"].apply(lambda x: float("{:.6}".format(x)))
df["Recall"] = df["Recall"].apply(lambda x: float("{:.6}".format(x)))
df["Precision"] = df["Precision"].apply(lambda x: float("{:.6}".format(x)))
df["F1 Score"] = df["F1 Score"].apply(lambda x: float("{:.6}".format(x)))
ndf = df[['Directory Name','Kernel_Size', 'Num_ResBlocks', 'Num_Channels', 'Num_FC_Layers', 'Accuracy',"Recall","Precision","F1 Score"]]
ndf = ndf[ndf["Num_ResBlocks"] != 12]
ndf.sort_values(by=["Kernel_Size","Num_ResBlocks","Num_Channels"],inplace=True,)

ndf.to_csv("results.csv")
ndf
# Out:
#         Directory Name  Kernel_Size  Num_ResBlocks  Num_Channels  \
# 13  B16_N4_FC1_K3_AP20            3              4            16
# 5   B32_N4_FC1_K3_AP20            3              4            32
# 1   B16_N8_FC2_K3_AP20            3              8            16
# 14  B32_N8_FC2_K3_AP20            3              8            32
# 7   B16_N4_FC1_K5_AP20            5              4            16
# 0   B32_N4_FC1_K5_AP20            5              4            32
# 8   B16_N8_FC2_K5_AP20            5              8            16
# 4   B32_N8_FC2_K5_AP20            5              8            32
# 11  B16_N4_FC1_K7_AP20            7              4            16
# 10  B32_N4_FC1_K7_AP20            7              4            32
# 3   B16_N8_FC2_K7_AP20            7              8            16
# 12  B32_N8_FC2_K7_AP20            7              8            32
#
#     Num_FC_Layers  Accuracy    Recall  Precision  F1 Score
# 13              1  0.582472  0.581015   0.599142  0.585643
# ...

# %%
sns.boxplot(x='Num_Channels', y='Accuracy',hue="Kernel_Size", data=ndf,palette='Spectral')
plt.savefig("BvK.svg")

# %%
sns.boxplot(x='Num_ResBlocks', y='Accuracy',hue="Kernel_Size", data=ndf,palette='Spectral')
plt.savefig("NvK.svg")

# %%
sns.boxplot(x='Kernel_Size', y='Accuracy',hue="Num_ResBlocks", data=ndf,palette='Spectral')
plt.savefig("KvN.svg")

# %%
sns.boxplot(x='Num_Channels', y='Accuracy',hue="Num_ResBlocks", data=ndf,palette='Spectral')
plt.savefig("BvN.svg")

# %%
sns.boxplot(x='Kernel_Size', y='Accuracy',hue="Num_Channels", data=ndf,palette='Spectral')
plt.savefig("KvB.svg")

# %%
sns.boxplot(x='Num_ResBlocks', y='Accuracy',hue="Num_Channels", data=ndf,palette='Spectral')
plt.savefig("NvB.svg")

# %%
A = ndf['Directory Name'].reset_index()['Directory Name']

# %%
for i in range(len(ndf['Directory Name'])):
    n = A[i]
    if "12" not in n:
        a = '''
        %% Row {i}
        \\begin{{figure}}
            \\centering
            \\begin{{subfigure}}{{0.3\\linewidth}}
                \\centering
                \\includesvg[width=\\linewidth]{{res_imgs/{m}confMatrixTest.svg}}
                \\caption{{Confusion Matrix on Test}}
                \\label{{fig:confMatrixTest-{i}}}
            \\end{{subfigure}}
            \\begin{{subfigure}}{{0.3\\linewidth}}
                \\centering
                \\includesvg[width=\\linewidth]{{res_imgs/{m}Loss.svg}}
                \\caption{{Loss}}
                \\label{{fig:loss-{i}}}
            \\end{{subfigure}}
            \\begin{{subfigure}}{{0.3\\linewidth}}
                \\centering
                \\includesvg[width=\\linewidth]{{res_imgs/{m}metrics_mocro.svg}}
                \\caption{{Metrics Macro}}
                \\label{{fig:metricsMacro-{i}}}
            \\end{{subfigure}}

            \\caption{{Caption derived from the upper directory: {s}}}
            \\label{{fig:overallCaption-{i}}}
        \\end{{figure}}
        %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
        '''.format(i=i, m=n, s=n.replace("_", "\\_"))
        print(a)
# Out:
#         %% Row 0
#         \begin{figure}
#             \centering
#             \begin{subfigure}{0.3\linewidth}
#                 \centering
#                 \includesvg[width=\linewidth]{res_imgs/B16_N4_FC1_K3_AP20confMatrixTest.svg}
#                 \caption{Confusion Matrix on Test}
#                 \label{fig:confMatrixTest-0}
#             \end{subfigure}
#             \begin{subfigure}{0.3\linewidth}
#                 \centering
#                 \includesvg[width=\linewidth]{res_imgs/B16_N4_FC1_K3_AP20Loss.svg}
#                 \caption{Loss}
#                 \label{fig:loss-0}
#             \end{subfigure}
#             \begin{subfigure}{0.3\linewidth}
#                 \centering
#                 \includesvg[width=\linewidth]{res_imgs/B16_N4_FC1_K3_AP20metrics_mocro.svg}
#                 \caption{Metrics Macro}
#                 \label{fig:metricsMacro-0}
#             \end{subfigure}
#
# ...

# %%
a = '123467'

# %%
"13" in a
# Out:
# False

# %%
import os
from tqdm import tqdm
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import torch as T
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torchvision.utils import make_grid

import PIL.Image as Image

import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
import torchvision.models as models

# %%
from torchsummary import summary

# %%
class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size = 3):
        super(ResBlock, self).__init__()
        self.conv1 = nn.Sequential(
                        nn.Conv2d(in_channels, out_channels, kernel_size = kernel_size, stride = 1, padding = kernel_size//2),
                        nn.BatchNorm2d(out_channels),
                        nn.ReLU())
        self.conv2 = nn.Sequential(
                        nn.Conv2d(out_channels, out_channels, kernel_size = kernel_size, stride = 1, padding = kernel_size//2),
                        nn.BatchNorm2d(out_channels))
        self.relu = nn.ReLU()
        self.out_channels = out_channels
        
    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.conv2(out)
        out += residual
        out = self.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self,num_classes, num_channel, num_blocks, num_fc_layers, avg_pool_size, kernel_size = 3,):
        super(ResNet, self).__init__()

        self.resblocks = self._make_resblocks(num_channel, num_blocks,kernel_size)

        self.avg_pool = nn.AdaptiveAvgPool2d((avg_pool_size, avg_pool_size))

        self.fc_layers = self._make_fc_layers(num_channel* avg_pool_size * avg_pool_size, num_fc_layers,num_classes)

    def _make_resblocks(self, bloc_size, num_resblocks,kernel_size):
        layers = []
        layers.append(ResBlock(1, bloc_size,kernel_size))
        for _ in range(num_resblocks-1):
            layers.append(ResBlock(bloc_size, bloc_size,kernel_size))
        return nn.Sequential(*layers)

    def _make_fc_layers(self, fc_size, num_fc_layers,num_classes):
        layers = []
        for _ in range(num_fc_layers):
            layers.append(nn.Linear(fc_size, fc_size))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(fc_size,num_classes))
        return nn.Sequential(*layers)

    def forward(self, x):
        x = self.resblocks(x)
        x = self.avg_pool(x)
        x = T.flatten(x, 1)
        x = self.fc_layers(x)
        return x

# %%
block_sizes = [32,64]
num_layers =  [8]
kernels = [7]
AP = 20


for B in block_sizes:
    for n in num_layers:
        for k in kernels:    
            F = int(n/3)   
            model = ResNet(num_classes=4,num_channel=B,num_blocks=n,num_fc_layers=F,avg_pool_size=AP)
            print("hel")
            break
        break
    break
# Out:
# hel

# %%
resnet18 = models.resnet18(pretrained=False)
# Out:
# /home/dara/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/dara/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
summary(resnet18)
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# ├─Conv2d: 1-1                            9,408
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  36,864
# |    |    └─BatchNorm2d: 3-5             128
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─ReLU: 3-8                    --
# |    |    └─Conv2d: 3-9                  36,864
# |    |    └─BatchNorm2d: 3-10            128
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# ...

# %%
_ = summary(model,(1,48,48))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─Sequential: 1-1                        [-1, 32, 48, 48]          --
# |    └─ResBlock: 2-1                     [-1, 32, 48, 48]          --
# |    |    └─Sequential: 3-1              [-1, 32, 48, 48]          384
# |    |    └─Sequential: 3-2              [-1, 32, 48, 48]          9,312
# |    |    └─ReLU: 3-3                    [-1, 32, 48, 48]          --
# |    └─ResBlock: 2-2                     [-1, 32, 48, 48]          --
# |    |    └─Sequential: 3-4              [-1, 32, 48, 48]          9,312
# |    |    └─Sequential: 3-5              [-1, 32, 48, 48]          9,312
# |    |    └─ReLU: 3-6                    [-1, 32, 48, 48]          --
# |    └─ResBlock: 2-3                     [-1, 32, 48, 48]          --
# |    |    └─Sequential: 3-7              [-1, 32, 48, 48]          9,312
# |    |    └─Sequential: 3-8              [-1, 32, 48, 48]          9,312
# ...

# %%
model
# Out:
# ResNet(
#   (resblocks): Sequential(
#     (0): ResBlock(
#       (conv1): Sequential(
#         (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (conv2): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU()
#     )
#     (1): ResBlock(
#       (conv1): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (conv2): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
def relu(x):
    return np.maximum(0, x)

# %%
x = np.linspace(-12,12,1000)

# %%
plt.plot(x, relu(x), label='ReLU')
plt.xlabel('x')
plt.ylabel('ReLU(x)')
plt.title('ReLU Activation Function')
plt.grid(False)
plt.legend()
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.ylim(-10, 10)  # Set y-axis range
plt.savefig("relu.svg")
